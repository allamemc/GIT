# %% [markdown]
# Tiene una serie de 5 alumnos con sus notas con decimales. Mostrar las califaciones en un gráfico circular. (plot --- pie)

# %%
import matplotlib.pyplot as plt

manzanas = [9.4,7,6.7,4]
nombres = ["Jose","Carmelo","Diego","Allam"]
plt.pie(manzanas, labels=nombres)
plt.show()
